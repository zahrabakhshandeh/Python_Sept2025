# %% [markdown]
# #### Session07 (Dictionary)

# %%
patient_data_1 = ["Sara", "Ara", 42, 50, 130, 120]
# index --------> value
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "weight": 50,
    "bp":130,
    "blood_sugar":120
    }
# key: value 
print(type(patient_data_2))
print(len(patient_data_2))
# Out:
# <class 'dict'>
# 6

# %%
data = {}
print(type(data))
print(len(data))
# Out:
# <class 'dict'>
# 0

# %% [markdown]
# #### Read

# %%
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "blood_sugar":120
    }
print(patient_data_2)
print(patient_data_2["age"])
print(patient_data_2["bp"])
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'age': 42, 'blood_sugar': 120}
# 42
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 9
#       7 print(patient_data_2)
#       8 print(patient_data_2["age"])
# ----> 9 print(patient_data_2["bp"])
#
# KeyError: 'bp'

# %%
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "blood_sugar":120
    }
age = patient_data_2.get("age")
print(age)
bp = patient_data_2.get("bp", "Not Found")
print(bp)
# Out:
# 42
# Not Found

# %% [markdown]
# #### Add

# %%
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "blood_sugar":120,
    "height": 1.7
    }
patient_data_2["weight"] = 50 

patient_data_2["BMI"] = patient_data_2["weight"] / (patient_data_2["height"]**2)
print(patient_data_2)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'age': 42, 'blood_sugar': 120, 'height': 1.7, 'weight': 50, 'BMI': 17.301038062283737}

# %%
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara"
}
patient_data_2.update({"age":42,"blood_sugar":120,"height": 1.7})
print(patient_data_2)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'age': 42, 'blood_sugar': 120, 'height': 1.7}

# %% [markdown]
# ### Edit

# %%
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "blood_sugar":120,
    "height": 1.7
    }
patient_data_2["age"] = 50 
print(patient_data_2)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'age': 50, 'blood_sugar': 120, 'height': 1.7}

# %%
patient_data_2 = {
    "f_name":"Sara", 
    "l_name":"Ara",
    "age": 40
}
patient_data_2.update({"age":42,"blood_sugar":120,"height": 1.7})
print(patient_data_2)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'age': 42, 'blood_sugar': 120, 'height': 1.7}

# %% [markdown]
# #### Remove

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
result = data.pop("age")
print(data, result)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'weight': 50, 'bp': 130, 'blood_sugar': 120} 42

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
result = data.pop("age")
print(data, result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 8
#       1 data= {
#       2     "f_name":"Sara",
#       3     "l_name":"Ara",
#    (...)
#       6     "blood_sugar":120
#       7 }
# ----> 8 result = data.pop("age")
#       9 print(data, result)
#
# KeyError: 'age'

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
result = data.pop("age", "Not Found")
print(data, result)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'weight': 50, 'bp': 130, 'blood_sugar': 120} Not Found

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
result = data.popitem()
print(data, result)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'weight': 50, 'bp': 130} ('blood_sugar', 120)

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
del data["blood_sugar"]
print(data)
# Out:
# {'f_name': 'Sara', 'l_name': 'Ara', 'weight': 50, 'bp': 130}

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
del data
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 9
#       1 data= {
#       2     "f_name":"Sara",
#       3     "l_name":"Ara",
#    (...)
#       6     "blood_sugar":120
#       7 }
#       8 del data
# ----> 9 print(data)
#
# NameError: name 'data' is not defined

# %%
data= {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
data.clear()
print(data)
# Out:
# {}

# %% [markdown]
# ### Search

# %%
data = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
data_keys = data.keys()
print(data_keys)
data_values = data.values()
print(data_values)
data_items = data.items()
print(data_items)
# Out:
# dict_keys(['f_name', 'l_name', 'age', 'weight', 'bp', 'blood_sugar'])
# dict_values(['Sara', 'Ara', 42, 50, 130, 120])
# dict_items([('f_name', 'Sara'), ('l_name', 'Ara'), ('age', 42), ('weight', 50), ('bp', 130), ('blood_sugar', 120)])

# %%
if "age1" in data.keys():
    print(data["age1"])

# %%
if 50 in data.values():
    print("yes")
# Out:
# yes

# %%
if ("age", 42) in data.items():
    print("yes")
# Out:
# yes

# %%
if "age" in data:
    print(data["age"])
# Out:
# 42

# %% [markdown]
# #### Loop

# %%
data = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
for i in data:
    print(i)
# Out:
# f_name
# l_name
# age
# weight
# bp
# blood_sugar

# %%
data = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
for i in data.values():
    print(i)
# Out:
# Sara
# Ara
# 42
# 50
# 130
# 120

# %%
scores = [12, 16, 12, 16, 19]
for i, v in enumerate(scores):
    print(i, v)
# Out:
# 0 12
# 1 16
# 2 12
# 3 16
# 4 19

# %%
data = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "weight": 50,
    "bp":130,
    "blood_sugar":120
}
for k, v in data.items():
    print(k, v)
# Out:
# f_name Sara
# l_name Ara
# age 42
# weight 50
# bp 130
# blood_sugar 120

# %%
data = {
    "f_name":"Sara", 
    "l_name":"Ara", 
    "age":42,
    "medications": ["vitamin", "aspirin"],
    "lab_tests": {
        "blood_sugar": 120,
        "cholestreol": 90
    }
}
result = data["medications"][0]
print(result)
blood_sugar = data["lab_tests"]["blood_sugar"]
print(blood_sugar)
# Out:
# vitamin
# 120

# %% [markdown]
# ### Tuple

# %%
# list [] index value
# dict {} key: value 
# tuple () index value

# %%
data = (12, 45, 67, 20, 45)
print(data)
print(type(data))
print(len(data))
# Out:
# (12, 45, 67, 20, 45)
# <class 'tuple'>
# 5

# %%
t1 = ()
t2 = tuple()
print(type(t2))
print(len(t1))
# Out:
# <class 'tuple'>
# 0

# %%
t1 = (10,)
print(type(t1))
print(len(t1))
# Out:
# <class 'tuple'>
# 1

# %%
data = (12, 45, 6.7, 20, "python", True)
print(data)
print(data[2])
# Out:
# (12, 45, 6.7, 20, 'python', True)
# 6.7

# %%
data = (12, 45, 6.7, 20, "python", True)
data[1] = 400 
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 2
#       1 data = (12, 45, 6.7, 20, "python", True)
# ----> 2 data[1] = 400
#       3 print(data)
#
# TypeError: 'tuple' object does not support item assignment

# %%
data = (12, 45, 6.7, 20, "python", True)
print(data, type(data))
data = list(data)
print(data, type(data))
data[2] = 400 
data.pop(0)
print(data, type(data))
data = tuple(data)
print(data, type(data))
# Out:
# (12, 45, 6.7, 20, 'python', True) <class 'tuple'>
# [12, 45, 6.7, 20, 'python', True] <class 'list'>
# [45, 400, 20, 'python', True] <class 'list'>
# (45, 400, 20, 'python', True) <class 'tuple'>

# %%
numbers = 12, 45, 56, 20 
print(numbers)
# Out:
# (12, 45, 56, 20)

# %%
list1 = [45, 67, 88]
result = list(enumerate(list1))
print(result)
# Out:
# [(0, 45), (1, 67), (2, 88)]

# %%
def get_data():
    while True:
        age = int(input("data1: "))
        bp = int(input("data2: "))
        if age > 0 and bp > 0:
            return age, bp

# %%
data1, data2 = get_data()
print(data1, data2)
# Out:
# 29 120

# %%
result = get_data()
print(result[0])
# Out:
# 34

# %% [markdown]
# #### Set

# %%
ids = {"P001", "P005", "P002", "P006"}
print(type(ids))
print(len(ids))
# Out:
# <class 'set'>
# 4

# %%
set1 = set()
print(type(set1))
# Out:
# <class 'set'>

# %%
ids = {"P001", "P005", "P002", "P006", "P001", "P005", "P001"}
print(type(ids))
print(len(ids))
print(ids)
# Out:
# <class 'set'>
# 4
# {'P002', 'P005', 'P001', 'P006'}

# %%
set1 = {True, 1, 0, 1.0, 0.0, "", False}
print(len(set1))
print(set1)
# True, 1, 1.0 
# False, 0, 0.0
# Out:
# 3
# {0, True, ''}

# %%
ids = {"P001", "P005", "P001", "P002", "P006"}
for i in ids: 
    print(i)
# Out:
# P002
# P005
# P001
# P006

# %%
#add
ids = {"P001", "P005", "P001", "P002", "P006"}
ids.add("P001")
print(ids)
# Out:
# {'P002', 'P005', 'P001', 'P006'}

# %%
ids = {"P001", "P005", "P001", "P002", "P006"}
ids.remove("P008")
print(ids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 2
#       1 ids = {"P001", "P005", "P001", "P002", "P006"}
# ----> 2 ids.remove("P008")
#       3 print(ids)
#
# KeyError: 'P008'

# %%
ids = {"P001", "P005", "P001", "P002", "P006"}
ids.discard("P008")
print(ids)
# Out:
# {'P002', 'P005', 'P001', 'P006'}

# %%
list1 = [12, 56, 34, 23, 12, 23, 34, 50]
list2 = []
for i in list1:
    if i not in list2:
        list2.append(i)
print(list2)
# Out:
# [12, 56, 34, 23, 50]

# %%
list1 = [12, 56, 34, 23, 12, 23, 34, 50]
new_data = list(set(list1))
print(new_data)
# Out:
# [34, 12, 50, 23, 56]
